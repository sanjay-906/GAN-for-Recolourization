# %% [markdown]
# ## Plot Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Images generated after 1 epoch

# %% [markdown]
# ### 100 images

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 200 images

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 400 images

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 800 images

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1000 images

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 1500 images

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 2000 images

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Error data

# %% [markdown]
# | Images model trained for | Mean Square Error |
# | --- | --- |
# | 100 |0.20679235957032704|
# | 200 |0.11602739397120963|
# | 300 |0.08406005752538037|
# | 400 |0.06796402623771941|
# | 500 |0.01372309922781228|
# | 600 |0.02834|
# | 700 |0.011151765353122645|
# | 800 |0.008819709469511388|
# | 900 |0.0365|
# | 1000 |0.0091|
# | 1100 |0.20679235957032704|
# | 1200 |0.11602739397120963|
# | 1300 |0.08406005752538037|
# | 1400 |0.06796402623771941|
# | 1500 |0.01372309922781228|
# | 1600 |0.02834|
# | 1700 |0.011151765353122645|
# | 1800 |0.008819709469511388|
# | 1900 |0.0365|
# | 2000 |0.0091|

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000]
y = [0.10350165245009167,
         0.04806285141617365,
         0.0360460816924212,
         0.03978414078098124,
         0.03181202116881663,
         0.03403650924686567,
         0.01619563485129998,
         0.0174562594750255,
         0.017912040304553845,
         0.015572027579279956,
         0.014957716298114744,
         0.013182539889725174,
         0.01399159695702113,
         0.01390376630903175,
         0.012668548085370171,
         0.013865757700390677,
         0.011905262822482221,
         0.012928424073271013,
         0.012736384924256943,
         0.009975338336395797]
plt.plot(x, y)

plt.title("Mean squared error (Single Epoch)")
plt.xlabel("Images model trained for")
plt.ylabel("Error")

plt.show()

# %% [markdown]
# # Comparison with pix2pix (tensorflow model)

# %% [markdown]
# ### Trained with 2k steps

# %% [markdown]
# Below is the predicted input image , Ground truth and predicted image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color='red'>Error of pix2pix = 0.02</font>
#
# ## <font color='green'>Error of Our model = 0.009</font>
